# %%
import geopandas as gpd

# %%
full_data = gpd.read_file(r'C:\Users\Giacomo\Downloads\Forest_Blocks_Linkages\MatrixForestBlocks.shp')

# %%
full_data.head()
# Out:
#       PERIMETER          NAME  NUM_ID1005 ECOREG   ACRES STATEPROV1  \
# 0   31311.23363   Coles Creek        1130    STL   12725         NY
# 1   40096.17434     Lyonsdale        1137    STL   17809         NY
# 2   94756.16368    White Face        1107    NAP   55720         NY
# 3  102207.89953  Jordan River         956    NAP   55633         NY
# 4  216861.94379    High Peaks         900    NAP  480965         NY
#
#   STATEPROV2 STATEPROV3  TIER SRC_DATE ELU_GRP ELU_SUBGRP ELU_SUBSUB  \
# 0       None       None     2    11/02       4         4a       None
# 1       None       None     1    11/02       1         1b       None
# 2       None       None     1     6/05      A1        A1a       A1a4
# 3       None       None     1     6/05      A1        A1a       A1a5
# 4       None       None     1     6/05      A1        A1a       A1a4
#
#    SUBGRP_NUM ELUGRP_TXT  NUMID0603  TIER1WSRO    SHAPE_AREA      SHAPE_LEN  \
# ...

# %%
data2 = gpd.read_file(r'C:\Users\Giacomo\Downloads\Forest_Blocks_Linkages\ForestBlockLinkages.shp')

# %%
data2.head()
# Out:
#    EXTENDS     SHAPE_LEN                                           geometry
# 0        0   9373.045395  LINESTRING Z (553728.854 4563269.635 0.000, 55...
# 1        0   4054.266640  LINESTRING Z (566103.604 4567926.512 0.000, 56...
# 2        0   2752.927833  LINESTRING Z (584051.153 4585398.934 0.000, 58...
# 3        0  52073.705025  LINESTRING Z (579209.816 4587071.454 0.000, 57...
# 4        0  21073.783085  LINESTRING Z (600159.021 4595126.066 0.000, 60...

# %%
data3 = gpd.read_file(r'C:\Users\Giacomo\Downloads\Forest_Blocks_Linkages\LinkageZones.shp')

# %%
data3.head()
# Out:
#    EXTENDS    SHAPE_AREA      SHAPE_LEN  \
# 0        0  6.319021e+05    3207.981143
# 1        0  3.221615e+08  157650.094614
# 2        0  1.863539e+06    5578.141653
# 3        0  1.202920e+08   77161.611570
# 4        0  3.575051e+08  162790.224825
#
#                                             geometry
# 0  POLYGON Z ((555581.744 4623735.000 0.000, 5555...
# 1  MULTIPOLYGON Z (((579741.576 4587190.029 0.000...
# 2  POLYGON Z ((555581.744 4623735.000 0.000, 5555...
# 3  MULTIPOLYGON Z (((578873.355 4633645.931 0.000...
# 4  POLYGON Z ((647651.744 4647825.000 0.000, 6483...

# %%
data = data3.copy()

# %%
data.plot()

# %%
full_data.plot()

# %%
data2.plot()

# %%
wells = gpd.read_file(r'C:\Users\Giacomo\Downloads\waterwells.shp')

# %%
wells.head()
# Out:
#    County    Town DEC_Well_N       Foil_Loc    Latitude   Longitude  \
# 0  ALBANY  Albany      A1046            N/A  42 41 24.7  73 49 49.4
# 1  ALBANY  Albany      A2129   CAVALLERI ST  42 38 19.1  73 46 33.0
# 2  ALBANY  Albany      A2138       YATES ST  42 39 43.0  73 47 10.0
# 3  ALBANY  Albany      A2204           I-87  42 38 19.0  73 47 42.2
# 4  ALBANY  Albany       A859  PITCH PINE RD  42 42 09.0  73 52 07.0
#
#   Well_Depth Rock_Depth GW_Depth Cased_Dept SCR YT_AvgDisc  RegNumber  \
# 0        139        135       39        139   N         73  NYRD10002
# 1        500         92       78        100   N          3  NYRD10005
# 2        485        200     None        215   N       None  NYRD10005
# 3        600         90     None         93   N          0  NYRD10031
# 4         20       -999       13         19   Y         10  NYRD10004
#
#        DDLAT     DDLONG                        geometry
# 0  42.690194 -73.830389  POINT (595811.320 4727074.506)
# ...

# %%
import matplotlib.pyplot as plt

wells.plot( color='green', edgecolor='gainsboro', zorder=3, figsize = (20,14))

# %%
wells.geometry.head()
# Out:
# 0    POINT (595811.320 4727074.506)
# 1    POINT (600363.316 4721412.887)
# 2    POINT (599483.530 4723988.674)
# 3    POINT (598787.408 4721387.171)
# 4    POINT (592661.932 4728398.331)
# Name: geometry, dtype: geometry

# %%
barc1 = gpd.read_file('https://raw.githubusercontent.com/martgnz/bcn-geodata/master/area-estadistica-basica/area-estadistica-basica.geojson')
barc2 = gpd.read_file('https://raw.githubusercontent.com/martgnz/bcn-geodata/master/barris/barris.geojson')
barc3 = gpd.read_file('https://raw.githubusercontent.com/martgnz/bcn-geodata/master/districtes/districtes.geojson')
barc4 = gpd.read_file('https://raw.githubusercontent.com/martgnz/bcn-geodata/master/gran-barri/gran-barri.geojson')
barc5 = gpd.read_file('https://raw.githubusercontent.com/martgnz/bcn-geodata/master/seccio-censal/seccio-censal.geojson')
barc6 = gpd.read_file('https://raw.githubusercontent.com/martgnz/bcn-geodata/master/terme-municipal/terme-municipal.geojson')
barc7 = gpd.read_file('https://raw.githubusercontent.com/martgnz/bcn-geodata/master/zona-urban-audit/zona-urban-audit.geojson')

# %%
#barc6 contains the boundaries

# %%
barc5.head(10000)
# Out:
#      ID_ANNEX ANNEXDESCR ID_TEMA               TEMA_DESCR ID_CONJUNT  \
# 0          01   Grup - I    0104  Unitats Administratives     010415
# 1          01   Grup - I    0104  Unitats Administratives     010415
# 2          01   Grup - I    0104  Unitats Administratives     010415
# 3          01   Grup - I    0104  Unitats Administratives     010415
# 4          01   Grup - I    0104  Unitats Administratives     010415
# ...       ...        ...     ...                      ...        ...
# 1065       01   Grup - I    0104  Unitats Administratives     010415
# 1066       01   Grup - I    0104  Unitats Administratives     010415
# 1067       01   Grup - I    0104  Unitats Administratives     010415
# 1068       01   Grup - I    0104  Unitats Administratives     010415
# 1069       01   Grup - I    0104  Unitats Administratives     010415
#
#          CONJ_DESCR ID_SUBCONJ     SCONJ_DESC  ID_ELEMENT  \
# 0     Secció censal   01041501  Secció censal  0104150101
# ...

# %%
ax = barc6.plot(figsize=(10,10), color='none', edgecolor='gainsboro', zorder=3)
#barc2.plot(color='maroon', markersize=2, ax=ax)
#barc3.plot(color='green', ax=ax)
#barc4.plot(color='yellow', markersize=2, ax=ax)
#barc5.plot(color='red', ax=ax)
#barc1.plot(color='blue', markersize=2, ax = ax)
#barc7.plot(color='blue', markersize=2, ax=ax)

# %%
a = 'git test'
